# %%
import json
import pandas as pd

# %%
with open('hh.json') as file:
    data = json.load(file)

# %%
df_hh = pd.DataFrame(data)

# %%
display(df_hh)
# Out:
#                                                                                  vacancy min_salary max_salary currency                            link             date    source_site
# 0                                                                     Разработчик Python       None       None     None  https://hh.ru/vacancy/47731802  10 февраля10.02  https://hh.ru
# 1                                                           Python разработчик (Персона)       None       None     None  https://hh.ru/vacancy/50731247  10 февраля10.02  https://hh.ru
# 2                                                             Backend разработчик Python       None       None     None  https://hh.ru/vacancy/52030162  11 февраля11.02  https://hh.ru
# 3                                                                Middle Python developer    150 000    200 000     руб.  https://hh.ru/vacancy/48586304  12 февраля12.02  https://hh.ru
# ...

# %%
with open('sj.json') as file:
    data = json.load(file)

# %%
df_sj = pd.DataFrame(data)

# %%
display(df_sj)
# Out:
#                                                                           vacancy min_salary max_salary currency                                                                                                                      link              date              source_site
# 0                                                              Разработчик Python     100000     120000     руб.                                                        https://www.superjob.ru/vakansii/razrabotchik-python-41681394.html  11 February 2022  https://www.superjob.ru
# 1                                                      Backend Developer / Python     320000     350000     руб.                                                          https://www.superjob.ru/vakansii/backend-developer-41250613.html        10 февраля  https://www.superjob.ru
# ...
